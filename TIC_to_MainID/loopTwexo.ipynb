# %%
'''
runs the command (twexo) in the command prompt automattically and it will create
a html file in the folder you're running the code in 
- part 1 of code

*need to clone tess-web-exploder-master in order to use this command
'''

import os
#os.system('test')
original = open('TESSsearch.txt','r')
starList = original.readlines()
for name in starList:
    #print('python C:\\Users\\ehu-21\\EXP2020\\tess-web-exploder-master\\twexo.py -t '+name+' --noweb')
    command = 'python C:\\Users\\ehu-21\\EXP2020\\tess-web-exploder-master\\twexo.py -t '+name.strip()+' --noweb'
    print(command)
    os.system(command)
# Out:
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 2760710 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 7624182 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 9033144 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 9348006 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 13499636 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 14091633 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 14165625 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 20178111 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 22843856 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 28230919 --noweb
# python C:\Users\ehu-21\EXP2020\tess-web-exploder-master\twexo.py -t 29191596 --noweb
# ...
