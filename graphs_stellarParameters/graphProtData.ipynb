# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
from sklearn.linear_model import LinearRegression
from mlxtend.plotting import plot_linear_regression


vPlanets = genfromtxt('n,v,e,prot,e,teff,e,logg,e,feh,e,kepMag,e,parallax,e.csv',delimiter=',',dtype='str')

#prot v. data
vsini = np.asfarray(vPlanets[:,1],float)
prot = np.asfarray(vPlanets[:,3],float)
teff = np.asfarray(vPlanets[:,5],float)
logg = np.asfarray(vPlanets[:,7],float)
feh = np.asfarray(vPlanets[:,9],float)
KepMag = np.asfarray(vPlanets[:,11],float)
parallax = np.asfarray(vPlanets[:,13],float)

#linear_regressor = LinearRegression()  # create object for the class
#linear_regressor.fit(p, v)  # perform linear regression
#Y_pred = linear_regressor.predict(p)  # make predictions

#intercept, slope, corr_coeff = plot_linear_regression(p, v)
#shorter rotation = higher vsini
plt.scatter(teff, prot, s=np.pi)
#plt.plot(p, Y_pred, color='red')
#plt.errorbar(p, v, yerr=e_v, fmt='.k')
plt.xlabel("teff")
plt.ylabel("prot")
plt.show()

plt.scatter(logg, prot, s=np.pi)
plt.xlabel("logg")
plt.ylabel("prot")
plt.show()

plt.scatter(feh, prot, s=np.pi)
plt.xlabel("feh")
plt.ylabel("prot")
plt.show()

plt.scatter(KepMag, prot, s=np.pi)
plt.xlabel("Kepler Magnitude")
plt.ylabel("prot")
plt.show()

plt.scatter(parallax, prot, s=np.pi)
plt.xlabel("parallax")
plt.ylabel("prot")
plt.show()

plt.scatter(vsini, prot, s=np.pi)
plt.xlabel("vsini")
plt.ylabel("prot")
plt.show()
