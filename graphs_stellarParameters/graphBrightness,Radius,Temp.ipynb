# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
from sklearn.linear_model import LinearRegression
from mlxtend.plotting import plot_linear_regression


vPlanets = genfromtxt('n,r,KepMag,teff,e.csv',delimiter=',',dtype='str')

#prot v. data
radius = np.asfarray(vPlanets[:,1],float)
KepMag = np.asfarray(vPlanets[:,2],float)
teff = np.asfarray(vPlanets[:,3],float)

#linear_regressor = LinearRegression()  # create object for the class
#linear_regressor.fit(p, v)  # perform linear regression
#Y_pred = linear_regressor.predict(p)  # make predictions

#intercept, slope, corr_coeff = plot_linear_regression(p, v)
#shorter rotation = higher vsini
plt.scatter(KepMag, radius, s=np.pi)
#plt.plot(p, Y_pred, color='red')
#plt.errorbar(p, v, yerr=e_v, fmt='.k')
plt.xlabel("Kepler Magnitude")
plt.ylabel("radius")
plt.show()

plt.scatter(teff, radius, s=np.pi)
plt.xlabel("teff")
plt.ylabel("radius")
plt.show()

plt.scatter(teff, KepMag, s=np.pi)
plt.xlabel("teff")
plt.ylabel("Kepler Magnitude")
plt.show()
#expected results: bigger star = brighter and hotter
