# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy import genfromtxt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
from sklearn.linear_model import LinearRegression
from mlxtend.plotting import plot_linear_regression


vPlanets = genfromtxt('n,#planets,v,e,prot,e,teff,e,logg,e,feh,e,KepMag,e,parallax,e.csv',delimiter=',',dtype='str')

#vsini v. #planets
numPlanets = np.asfarray(vPlanets[:,1],float)
vsini = np.asfarray(vPlanets[:,2],float)
prot = np.asfarray(vPlanets[:,4],float)
teff = np.asfarray(vPlanets[:,6],float)
logg = np.asfarray(vPlanets[:,8],float)
feh = np.asfarray(vPlanets[:,10],float)
KepMag = np.asfarray(vPlanets[:,12],float)
parallax = np.asfarray(vPlanets[:,14],float)

#linear_regressor = LinearRegression()  # create object for the class
#linear_regressor.fit(p, v)  # perform linear regression
#Y_pred = linear_regressor.predict(p)  # make predictions

#intercept, slope, corr_coeff = plot_linear_regression(p, v)
#shorter rotation = higher vsini
plt.scatter(vsini, numPlanets, s=np.pi)
#plt.plot(p, Y_pred, color='red')
#plt.errorbar(p, v, yerr=e_v, fmt='.k')
plt.xlabel("vsini")
plt.ylabel("numPlanets")
plt.show()

plt.scatter(prot, numPlanets, s=np.pi)
plt.xlabel("prot")
plt.ylabel("numPlanets")
plt.show()

plt.scatter(teff, numPlanets, s=np.pi)
plt.xlabel("teff")
plt.ylabel("numPlanets")
plt.show()

plt.scatter(logg, numPlanets, s=np.pi)
plt.xlabel("logg")
plt.ylabel("numPlanets")
plt.show()

plt.scatter(feh, numPlanets, s=np.pi)
plt.xlabel("feh")
plt.ylabel("numPlanets")
plt.show()

plt.scatter(KepMag, numPlanets, s=np.pi)
plt.xlabel("Kepler Magnitude")
plt.ylabel("numPlanets")
plt.show()

plt.scatter(parallax, numPlanets, s=np.pi)
plt.xlabel("parallax")
plt.ylabel("numPlanets")
plt.show()
